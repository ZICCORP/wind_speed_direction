# %% [markdown]
# ### import os for  operating system operations e.g., creating a folder

# %%
import os

# %% [markdown]
# ### Tensorflow and keras are two packages for creating neural network models.

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ### For splitting our dataset into training and test set

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### print tensorflow (TF) version. Make sure you have at least tensorflow 2.1.0

# %%
print(f"Tensorflow version: {tf.version.VERSION}")
# Out:
# Tensorflow version: 2.6.0

# %%
import pathlib # for processing a path e.g c:\documents\files\testset.csv
import matplotlib.pyplot as plt # for plotting data and creating different charts.
import numpy as np # for math and arrays
import pandas as pd # data frame for the data.
import seaborn as sns # plotting.

# %% [markdown]
# ### Read dataset

# %%
dataset = pd.read_csv('dataset2.csv')

# %% [markdown]
# ### display dataset

# %%
true_values = dataset['WIND-DIRECTION']
dataset.head(-10)
# Out:
#        DATE  MAXIMUM-TEMPERATURE  MINIMUM-TEMPERATURE  WIND-DIRECTION  \
# 0    Jan-95                 33.3                 16.4              73
# 1    Feb-95                 35.9                 18.6             123
# 2    Mar-95                 40.5                 25.0             191
# 3    Apr-95                 40.1                 27.2             196
# 4    May-95                 36.8                 25.7             155
# ..      ...                  ...                  ...             ...
# 303     NaN                 40.7                 29.4             270
# 304     NaN                 37.7                 27.2             240
# 305     NaN                 33.8                 25.4             230
# 306     NaN                 31.5                 24.2             220
# 307     NaN                 31.8                 24.4             270
#
#      WIND-SPEED  WIND-RUN  RELATIVE-HUMIDITY  AIR-PRESSURE
# 0           2.0       NaN                 27        1014.5
# 1           3.0       NaN                 23        1013.7
# 2           3.0       NaN                 32        1009.1
# 3           4.0       NaN                 43        1010.5
# 4           3.0       NaN                 61        1010.3
# ..          ...       ...                ...           ...
# 303         1.5      47.4                 48        1003.3
# 304         2.1      52.8                 61        1005.7
# 305         1.9      52.1                 72        1008.3
# 306         1.9      46.4                 79        1010.0
# 307         1.6      42.4                 76        1009.6
#
# [308 rows x 8 columns]

# %% [markdown]
# ### dataset characteristics

# %%
dataset.describe()
# Out:
#        MAXIMUM-TEMPERATURE  MINIMUM-TEMPERATURE  WIND-DIRECTION  WIND-SPEED  \
# count           318.000000           318.000000      318.000000  318.000000
# mean             35.168868            23.039937      165.679245    3.449686
# std               3.219431             3.183020       54.287681    1.456645
# min              28.500000            13.900000       58.000000    0.000000
# 25%              32.200000            21.000000      120.000000    2.225000
# 50%              35.000000            23.600000      163.500000    3.000000
# 75%              37.300000            25.000000      204.750000    4.000000
# max              41.900000            29.400000      307.000000   12.000000
#
#         WIND-RUN  RELATIVE-HUMIDITY  AIR-PRESSURE
# count  66.000000         318.000000    318.000000
# mean   48.207576          53.556604   1011.990566
# std    16.390328          21.502584      3.587883
# min    18.900000          11.000000   1002.300000
# 25%    33.300000          32.000000   1010.400000
# 50%    47.600000          54.000000   1013.200000
# 75%    61.350000          75.000000   1014.300000
# max    98.300000          85.000000   1036.000000

# %% [markdown]
# ### Check for null and NaN values

# %%
dataset.isna().sum()
# Out:
# DATE                   113
# MAXIMUM-TEMPERATURE      0
# MINIMUM-TEMPERATURE      0
# WIND-DIRECTION           0
# WIND-SPEED               0
# WIND-RUN               252
# RELATIVE-HUMIDITY        0
# AIR-PRESSURE             0
# dtype: int64

# %%
median =dataset['WIND-RUN'].median()
median
dataset["WIND-RUN"].fillna(median, inplace=True)

# %% [markdown]
# ### copy dataset

# %%
dataset.head(-10)
# Out:
#        DATE  MAXIMUM-TEMPERATURE  MINIMUM-TEMPERATURE  WIND-DIRECTION  \
# 0    Jan-95                 33.3                 16.4              73
# 1    Feb-95                 35.9                 18.6             123
# 2    Mar-95                 40.5                 25.0             191
# 3    Apr-95                 40.1                 27.2             196
# 4    May-95                 36.8                 25.7             155
# ..      ...                  ...                  ...             ...
# 303     NaN                 40.7                 29.4             270
# 304     NaN                 37.7                 27.2             240
# 305     NaN                 33.8                 25.4             230
# 306     NaN                 31.5                 24.2             220
# 307     NaN                 31.8                 24.4             270
#
#      WIND-SPEED  WIND-RUN  RELATIVE-HUMIDITY  AIR-PRESSURE
# 0           2.0      47.6                 27        1014.5
# 1           3.0      47.6                 23        1013.7
# 2           3.0      47.6                 32        1009.1
# 3           4.0      47.6                 43        1010.5
# 4           3.0      47.6                 61        1010.3
# ..          ...       ...                ...           ...
# 303         1.5      47.4                 48        1003.3
# 304         2.1      52.8                 61        1005.7
# 305         1.9      52.1                 72        1008.3
# 306         1.9      46.4                 79        1010.0
# 307         1.6      42.4                 76        1009.6
#
# [308 rows x 8 columns]

# %%
df = dataset[:]

# %% [markdown]
# ### remove the date column

# %%
del df['DATE']

# %%
df
# Out:
#      MAXIMUM-TEMPERATURE  MINIMUM-TEMPERATURE  WIND-DIRECTION  WIND-SPEED  \
# 0                   33.3                 16.4              73         2.0
# 1                   35.9                 18.6             123         3.0
# 2                   40.5                 25.0             191         3.0
# 3                   40.1                 27.2             196         4.0
# 4                   36.8                 25.7             155         3.0
# ..                   ...                  ...             ...         ...
# 313                 36.0                 22.4             170         3.4
# 314                 39.7                 26.1             220         2.1
# 315                 39.7                 28.8             200         4.6
# 316                 35.6                 25.3             130         2.6
# 317                 32.8                 23.8             160         3.6
#
#      WIND-RUN  RELATIVE-HUMIDITY  AIR-PRESSURE
# 0        47.6                 27        1014.5
# 1        47.6                 23        1013.7
# 2        47.6                 32        1009.1
# 3        47.6                 43        1010.5
# 4        47.6                 61        1010.3
# ..        ...                ...           ...
# 313      63.7                 26        1006.9
# 314      73.7                 35        1005.6
# 315      84.2                 65        1002.6
# 316      98.3                 75        1005.4
# 317      18.9                 77        1007.6
#
# [318 rows x 7 columns]

# %%
print(f'Number of rows/example and columns in the dataset: {df.shape}')
# Out:
# Number of rows/example and columns in the dataset: (318, 7)

# %% [markdown]
# ### Summary of information on the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318 entries, 0 to 317
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MAXIMUM-TEMPERATURE  318 non-null    float64
#  1   MINIMUM-TEMPERATURE  318 non-null    float64
#  2   WIND-DIRECTION       318 non-null    int64
#  3   WIND-SPEED           318 non-null    float64
#  4   WIND-RUN             318 non-null    float64
#  5   RELATIVE-HUMIDITY    318 non-null    int64
#  6   AIR-PRESSURE         318 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 17.5 KB

# %% [markdown]
# ### Split the data into train/test splits

# %% [markdown]
# #### Split the data into 60% train and 40% test (later will divide the test to test and validate)

# %%
train_dataset, temp_test_dataset = train_test_split(df, test_size=0.4)

print( train_dataset.shape)
print( temp_test_dataset.shape)
# Out:
# (190, 7)
# (128, 7)

# %% [markdown]
# ### Split the test_dataset dataframe to 50% test and 50% validation.

# %%
test_dataset, valid_dataset = train_test_split(temp_test_dataset, test_size=0.5)
print(test_dataset.shape)
print(valid_dataset.shape)
# Out:
# (64, 7)
# (64, 7)

# %%
print(f"Display the datatype of the test_dataset: {type(test_dataset)}")
print(f"Train dataset      : {train_dataset.shape}")
print(f"Test dataset       : {test_dataset.shape}")
print(f"Validation dataset : {valid_dataset.shape}")
# Out:
# Display the datatype of the test_dataset: <class 'pandas.core.frame.DataFrame'>
# Train dataset      : (190, 7)
# Test dataset       : (64, 7)
# Validation dataset : (64, 7)

# %% [markdown]
# ## Plot the relationship between each two variables to spot anything incorrect.

# %%
train_stats = train_dataset.describe()
train_stats.pop("WIND-DIRECTION")
sns.pairplot(train_stats[train_stats.columns], diag_kind="kde") # or diag_kind='reg'

# %% [markdown]
# ### Statistics on the train dataset to make sure it in a good shape

# %%
train_stats = train_dataset.describe()
wind_direction=train_stats.pop("WIND-DIRECTION")
train_stats = train_stats.transpose()
#train_stats
wind_direction
# Out:
# count    190.000000
# mean     167.152632
# std       56.546585
# min       58.000000
# 25%      120.000000
# 50%      169.000000
# 75%      210.750000
# max      307.000000
# Name: WIND-DIRECTION, dtype: float64

# %% [markdown]
# ## The label is "WIND-DIRECTION"

# %%
train_labels = train_dataset.pop('WIND-DIRECTION')
test_labels = test_dataset.pop('WIND-DIRECTION')
valid_labels = valid_dataset.pop('WIND-DIRECTION')

# %% [markdown]
# ## Data Normalization/Scaling

# %% [markdown]
# ## Subtract the mean of the training data and divide by the standard deviation

# %% [markdown]
# ### define a function to normalize the data set.

# %%
from sklearn.preprocessing import MinMaxScaler

def norm(x):
    cols_to_scale= ['MAXIMUM-TEMPERATURE','MINIMUM-TEMPERATURE','WIND-SPEED','RELATIVE-HUMIDITY','WIND-RUN','AIR-PRESSURE']
    scaler = MinMaxScaler()
    x[cols_to_scale] = scaler.fit_transform(x[cols_to_scale])
    return x
      #return (x - train_stats['mean'] / train_stats['std'])
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)
normed_valid_dataset = norm(valid_dataset)
# Out:
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
print(f'Train/Test/Validate splits: ')
print(f'Train       : {normed_train_data.shape} ')
print(f'Test        : {normed_test_data.shape} ')
print(f'Validate    : {normed_valid_dataset.shape} ')

print(f'Train/Test/Validate labels: ')
print(f'Train Labels : {train_labels.shape}')
print(f'Test Labels  : {test_labels.shape}')
print(f'Test Labels  : {valid_labels.shape}')
# Out:
# Train/Test/Validate splits:
# Train       : (190, 6)
# Test        : (64, 6)
# Validate    : (64, 6)
# Train/Test/Validate labels:
# Train Labels : (190,)
# Test Labels  : (64,)
# Test Labels  : (64,)

# %% [markdown]
# ## show a sample of the data after normalized

# %%
normed_train_data.head(10)
# Out:
#      MAXIMUM-TEMPERATURE  MINIMUM-TEMPERATURE  WIND-SPEED  WIND-RUN  \
# 188             0.194030             0.587838    0.571429  0.441113
# 186             0.216418             0.635135    0.571429  0.441113
# 50              0.932836             0.750000    0.571429  0.441113
# 97              0.768657             0.472973    0.285714  0.441113
# 58              0.537313             0.385135    0.428571  0.441113
# 278             0.880597             0.831081    0.171429  0.708779
# 309             0.440299             0.635135    0.142857  0.591006
# 209             0.320896             0.614865    0.714286  0.441113
# 66              0.216418             0.635135    0.142857  0.441113
# 51              0.902985             0.871622    0.714286  0.441113
#
#      RELATIVE-HUMIDITY  AIR-PRESSURE
# 188           0.955882      0.356083
# 186           0.941176      0.367953
# 50            0.294118      0.186944
# 97            0.132353      0.270030
# 58            0.544118      0.323442
# 278           0.279412      0.005935
# 309           0.750000      0.127596
# 209           0.779412      0.367953
# 66            0.970588      0.332344
# 51            0.382353      0.243323

# %% [markdown]
# ## Build a Neural Network Model

# %% [markdown]
# ### We declared a function for creating a model.

# %%
def model1_single_layer_perceptron():
    model = keras.Sequential([
       keras.layers.Dense(1,input_shape=(6,)) 
    ])
    model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae','mse','mape'])
    
    return model

# %%
model1 = model1_single_layer_perceptron()
print('Here is a summary of this model: ')
model1.summary()
# Out:
# Here is a summary of this model:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 7
# =================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## import NN and other components.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation,Dense,BatchNormalization,Dropout
from tensorflow.keras import optimizers

# %%
def model2_multilayer_perceptron_with_one_hidden_layer():
      model = Sequential()
     # The model so far is empty. It can be constructed by adding layers and compilation.
     # This Keras model with a single hidden layers.
        
     # Input Layer with 10 Neurons
      model.add(Dense(10, input_shape =(normed_train_data.shape[1],)))
 
      model.add(Dense(35, Activation('relu'))) # Hidden layer 1

      model.add(Dense(1))  # Output layer => output dimension = 1
    
      learning_rate = 0.001
    
      optimizer = optimizers.RMSprop(learning_rate)
  
      model.compile(loss='mse',optimizer=optimizer, metrics=['mae','mse','mape']) 
      return model

# %%
model2 = model2_multilayer_perceptron_with_one_hidden_layer()
print('Here is a summary of this model: ')
model2.summary()
# Out:
# Here is a summary of this model:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                70
# _________________________________________________________________
# dense_2 (Dense)              (None, 35)                385
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 36
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________

# %%
def model3_multilayer_perceptron_with_two_hidden_layer():
      model = Sequential()
     # The model so far is empty. It can be constructed by adding layers and compilation.
     # This Keras model with a single hidden layers.
        
     # Input Layer with 32 Neurons
      model.add(Dense(32, input_shape =(normed_train_data.shape[1],)))
 
      model.add(Dense(32, Activation('relu'))) # Hidden layer 1
    
      model.add(Dense(64, Activation('relu'))) # Hidden layer 2
    
      model.add(Dense(72, Activation('relu'))) # Hidden layer 2
 
      model.add(Dense(80, Activation('relu'))) # Hidden layer 2
    
      model.add(Dense(1,Activation('linear')))  # Output layer => output dimension = 1
    
      learning_rate = 0.001
    
      optimizer = optimizers.RMSprop(learning_rate)
  
      model.compile(loss='mse',optimizer=optimizer, metrics=['mae','mse','mape']) 
      return model

# %%
model3 = model3_multilayer_perceptron_with_two_hidden_layer()
print('Here is a summary of this model: ')


model3.summary()
# Out:
# Here is a summary of this model:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 32)                224
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_23 (Dense)             (None, 72)                4680
# _________________________________________________________________
# dense_24 (Dense)             (None, 80)                5840
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 13,993
# Trainable params: 13,993
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Test the model before training (this will use the initial weights)

# %%
example_result_1 = model1.predict(normed_train_data) # Here we are using the single layer perceptron model

# %% [markdown]
# ## Compare the predicted values with the actual values

# %%
print('Predicted Values')
print(example_result_1[:10])
print()
print('Actual Values')
print(train_labels[:10].to_string(index=False))
# Out:
# Predicted Values
# [[1.3737005 ]
#  [1.4017587 ]
#  [0.71617365]
#  [0.44953996]
#  [0.81964105]
#  [0.4541311 ]
#  [0.91369057]
#  [1.25212   ]
#  [1.3637315 ]
#  [0.93650955]]
#
# Actual Values
# 236
# 209
# 307
#  99
# 131
# 190
# 210
# 170
# 210
# 199

# %% [markdown]
# ## Save checkpoints during training

# %%
# checkpoint_path
checkpoint_path = r".\models\wind_direction_prediction.ckpt"

#create a callback that saves the model's weight
ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,monitor='val_loss',
                                                 save_best_only=True,verbose=0,)

# %% [markdown]
# ## Training the model we built above.

# %% [markdown]
# ### Training the single layer perceptron

# %%
# Tensorflow utils packages.
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling

# %%
# %%time

EPOCHS = 500
batch_size = 6

model1 = model1_single_layer_perceptron()
print('Here is a summary of this model: ')
model1.summary()

with tf.device('/CPU:0'):
    history = model1.fit(
        normed_train_data,
        train_labels,
        batch_size = batch_size,
        epochs=EPOCHS,
        verbose=0,
        shuffle=True,
        steps_per_epoch= 1,
        validation_data = (normed_valid_dataset, valid_labels),
        callbacks=[tfdocs.modeling.EpochDots(), ckpt_callback],
    )
# Out:
# Here is a summary of this model:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, loss:26668.5840,  mae:157.4916,  mape:99.7672,  mse:26668.5840,  val_loss:29735.3711,  val_mae:164.5713,  val_mape:99.9466,  val_mse:29735.3711,
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
#
# Epoch: 100, loss:34882.6719,  mae:174.0268,  mape:99.4912,  mse:34882.6719,  val_loss:29608.6562,  val_mae:164.1934,  val_mape:99.6956,  val_mse:29608.6562,
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
#
# Epoch: 200, loss:23298.4375,  mae:146.4129,  mape:99.1885,  mse:23298.4375,  val_loss:29481.6602,  val_mae:163.8138,  val_mape:99.4433,  val_mse:29481.6602,
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
#
# Epoch: 300, loss:22051.8145,  mae:143.7143,  mape:98.8198,  mse:22051.8145,  val_loss:29355.8477,  val_mae:163.4368,  val_mape:99.1928,  val_mse:29355.8477,
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
#
# Epoch: 400, loss:27109.9531,  mae:154.6568,  mape:98.6905,  mse:27109.9531,  val_loss:29229.7012,  val_mae:163.0579,  val_mape:98.9411,  val_mse:29229.7012,
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# .INFO:tensorflow:Assets written to: .\models\wind_direction_prediction.ckpt\assets
# Wall time: 10min 24s

# %%
print('Summary of the results after each epoch: ')
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Summary of the results after each epoch:
#              loss         mae           mse       mape      val_loss  \
# 495  49781.316406  214.911072  49781.316406  98.792053  29110.523438
# 496  37243.972656  183.155502  37243.972656  98.584961  29109.224609
# 497  26617.507812  153.356827  26617.507812  98.460579  29107.929688
# 498  19060.212891  130.385742  19060.212891  98.372917  29106.681641
# 499  24508.755859  151.112671  24508.755859  98.478607  29105.439453
#
#         val_mae       val_mse   val_mape  epoch
# 495  162.699203  29110.523438  98.702744    495
# 496  162.695297  29109.224609  98.700150    496
# 497  162.691406  29107.929688  98.697571    497
# 498  162.687637  29106.683594  98.695068    498
# 499  162.683899  29105.439453  98.692574    499

# %%
# Test the model after training
example_result_2 = model1.predict(normed_test_data)

# %% [markdown]
# ## Compare the predicted values with the actual values

# %%
print('Predicted Values')
print(example_result_2[:10])
print()
print('Actual Values')
print(test_labels[:10].to_string(index=False))
# Out:
# Predicted Values
# [[2.732339 ]
#  [1.8104296]
#  [1.4278803]
#  [2.0624542]
#  [2.0833726]
#  [1.786091 ]
#  [2.3140843]
#  [2.121931 ]
#  [2.2942386]
#  [2.0949879]]
#
# Actual Values
# 177
#  84
# 121
# 169
# 142
# 162
# 240
# 165
# 190
# 133

# %%
print('The ground truth: ')
train_labels[:10]
# Out:
# The ground truth:
# 188    236
# 186    209
# 50     307
# 97      99
# 58     131
# 278    190
# 309    210
# 209    170
# 66     210
# 51     199
# Name: WIND-DIRECTION, dtype: int64

# %% [markdown]
# ## See how the training went by plotting the loss/mse across epochs

# %%
plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)

plotter.plot({'Basic': history}, metric = 'mae')
plt.ylim([0,300])
plt.ylabel('MAE [wind-speed]')
# Out:
# Text(0, 0.5, 'MAE [wind-speed]')

# %%
plotter.plot({'Basic': history}, metric = 'mse')
plt.ylim([0,85000])
plt.ylabel('MSE [wind-speed]')
# Out:
# Text(0, 0.5, 'MSE [wind-speed]')

# %%
print('Error Rate on Train Split: ')
loss, mae, mse, mape = model1.evaluate(normed_train_data, train_labels, verbose=2)

print('Train set Mean Abs Error : {:5.2f}'.format(mae))
print('Train set Mean Square Error : {:5.2f}'.format(mse))
# Out:
# Error Rate on Train Split:
# 6/6 - 0s - loss: 30342.3418 - mae: 164.8812 - mse: 30342.3418 - mape: 98.4972
# Train set Mean Abs Error : 164.88
# Train set Mean Square Error : 30342.34

# %%
print('Error Rate on Evaluation  Split: ')
loss, mae, mse, mape = model1.evaluate(normed_valid_dataset, valid_labels, verbose=2)

print('Validation set Mean Abs Error : {:5.2f}'.format(mae))
print('Validation set Mean Square Error : {:5.2f}'.format(mse))
# Out:
# Error Rate on Evaluation  Split:
# 2/2 - 0s - loss: 29105.4414 - mae: 162.6839 - mse: 29105.4414 - mape: 98.6926
# Validation set Mean Abs Error : 162.68
# Validation set Mean Square Error : 29105.44

# %%
print('Error Rate on Test  Split: ')
loss, mae, mse, mape = model1.evaluate(normed_test_data, test_labels, verbose=2)

print('Testing set Mean Abs Error : {:5.2f}'.format(mae))
print('Testing set Mean Square Error : {:5.2f}'.format(mse))
# Out:
# Error Rate on Test  Split:
# 2/2 - 0s - loss: 28106.5391 - mae: 160.1646 - mse: 28106.5391 - mape: 98.5915
# Testing set Mean Abs Error : 160.16
# Testing set Mean Square Error : 28106.54

# %%
train_predictions = model1.predict(normed_train_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(train_labels, train_predictions)
plt.xlabel('True Values [wind-direction]')
plt.ylabel('Predictions [wind-direction]')
lims = [0, 350]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
test_predictions = model1.predict(normed_test_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [wind-speed]')
plt.ylabel('Predictions [wind-speed]')
lims = [0, 350]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
# error distribution.
error = test_predictions - test_labels
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error [medv]")
_ = plt.ylabel("count")

# %% [markdown]
# ## One hidden layer analysis

# %%
# checkpoint_path
checkpoint_path = r".\models\wind_direction_prediction2.ckpt"

#create a callback that saves the model's weight
ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,monitor='val_loss',
                                                 save_best_only=True,verbose=0,)

# %%
# %%time

EPOCHS = 500
batch_size = 6

model2 = model2_multilayer_perceptron_with_one_hidden_layer()
print('Here is a summary of this model: ')
model2.summary()

with tf.device('/CPU:0'):
    history = model2.fit(
        normed_train_data,
        train_labels,
        batch_size = batch_size,
        epochs=EPOCHS,
        verbose=0,
        shuffle=True,
        steps_per_epoch= 1,
        validation_data = (normed_valid_dataset, valid_labels),
        callbacks=[tfdocs.modeling.EpochDots(), ckpt_callback],
    )
# Out:
# Here is a summary of this model:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 10)                70
# _________________________________________________________________
# dense_12 (Dense)             (None, 35)                385
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 36
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, loss:20118.6094,  mae:139.2920,  mape:99.7244,  mse:20118.6094,  val_loss:29587.6641,  val_mae:164.1162,  val_mape:99.6319,  val_mse:29587.6641,
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# ...
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# ...
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# ...
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_fn, activation_6_layer_call_fn, activation_6_layer_call_and_return_conditional_losses, activation_6_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction2.ckpt\assets
# Wall time: 13min 31s

# %%
print('Summary of the results after each epoch: ')
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Summary of the results after each epoch:
#             loss        mae          mse       mape     val_loss    val_mae  \
# 495   731.557800  24.012100   731.557800  13.456680  2053.760986  35.799934
# 496  2784.357422  45.677982  2784.357422  37.087193  2048.401367  35.767002
# 497  4675.730469  60.573521  4675.730469  33.762371  2020.430908  35.591778
# 498   335.349396  13.421308   335.349396   9.799968  2018.077148  35.578140
# 499  4947.337402  68.536438  4947.337402  40.169880  1991.296021  35.468113
#
#          val_mse   val_mape  epoch
# 495  2053.760986  23.064049    495
# 496  2048.401367  23.077259    496
# 497  2020.430908  23.174696    497
# 498  2018.077148  23.182554    498
# 499  1991.296021  23.352642    499

# %%
# Test the model after training
example_result_3 = model2.predict(normed_test_data)

# %% [markdown]
# ## Compare the predicted values with the actual values

# %%
print('Predicted Values')
print(example_result_3[:10])
print()
print('Actual Values')
print(test_labels[:10].to_string(index=False))
# Out:
# Predicted Values
# [[207.22873 ]
#  [146.19075 ]
#  [120.516846]
#  [170.01187 ]
#  [175.62352 ]
#  [142.137   ]
#  [146.43845 ]
#  [168.46489 ]
#  [184.5481  ]
#  [165.95824 ]]
#
# Actual Values
# 177
#  84
# 121
# 169
# 142
# 162
# 240
# 165
# 190
# 133

# %%
print('Summary of the results after each epoch: ')
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Summary of the results after each epoch:
#             loss        mae          mse       mape     val_loss    val_mae  \
# 495   731.557800  24.012100   731.557800  13.456680  2053.760986  35.799934
# 496  2784.357422  45.677982  2784.357422  37.087193  2048.401367  35.767002
# 497  4675.730469  60.573521  4675.730469  33.762371  2020.430908  35.591778
# 498   335.349396  13.421308   335.349396   9.799968  2018.077148  35.578140
# 499  4947.337402  68.536438  4947.337402  40.169880  1991.296021  35.468113
#
#          val_mse   val_mape  epoch
# 495  2053.760986  23.064049    495
# 496  2048.401367  23.077259    496
# 497  2020.430908  23.174696    497
# 498  2018.077148  23.182554    498
# 499  1991.296021  23.352642    499

# %% [markdown]
# ## See how the training went by plotting the loss/mse across epochs

# %%
plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)

plotter.plot({'Basic': history}, metric = 'mae')
plt.ylim([0,150])
plt.ylabel('MAE [wind-direction]')
# Out:
# Text(0, 0.5, 'MAE [wind-direction]')

# %%
plotter.plot({'Basic': history}, metric = 'mse')
plt.ylim([0,5000])
plt.ylabel('MSE [wind-direction]')
# Out:
# Text(0, 0.5, 'MSE [wind-direction]')

# %%
print('Error Rate on Train Split: ')
loss, mae, mse, mape = model2.evaluate(normed_train_data, train_labels, verbose=2)

print('Train set Mean Abs Error : {:5.2f}'.format(mae))
print('Train set Mean Square Error : {:5.2f}'.format(mse))
# Out:
# Error Rate on Train Split:
# 6/6 - 0s - loss: 2367.9651 - mae: 39.4526 - mse: 2367.9651 - mape: 27.0657
# Train set Mean Abs Error : 39.45
# Train set Mean Square Error : 2367.97

# %%
print('Error Rate on Evaluation  Split: ')
loss, mae, mse, mape = model2.evaluate(normed_valid_dataset, valid_labels, verbose=2)

print('Validation set Mean Abs Error : {:5.2f}'.format(mae))
print('Validation set Mean Square Error : {:5.2f}'.format(mse))
# Out:
# Error Rate on Evaluation  Split:
# 2/2 - 1s - loss: 1991.2961 - mae: 35.4681 - mse: 1991.2961 - mape: 23.3526
# Validation set Mean Abs Error : 35.47
# Validation set Mean Square Error : 1991.30

# %%
print('Error Rate on Test  Split: ')
loss, mae, mse, mape = model2.evaluate(normed_test_data, test_labels, verbose=2)

print('Testing set Mean Abs Error : {:5.2f}'.format(mae))
print('Testing set Mean Square Error : {:5.2f}'.format(mse))
# Out:
# Error Rate on Test  Split:
# 2/2 - 0s - loss: 1946.1155 - mae: 35.7830 - mse: 1946.1155 - mape: 24.3937
# Testing set Mean Abs Error : 35.78
# Testing set Mean Square Error : 1946.12

# %%
train_predictions = model2.predict(normed_train_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(train_labels, train_predictions)
plt.xlabel('True Values [wind-speed]')
plt.ylabel('Predictions [wind-speed]')
lims = [0, 350]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
test_predictions = model2.predict(normed_test_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [wind-speed]')
plt.ylabel('Predictions [wind-speed]')
lims = [0, 350]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
# error distribution.
error = test_predictions - test_labels
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error [medv]")
_ = plt.ylabel("count")

# %% [markdown]
# ## Two hidden layer analysis

# %%
# checkpoint_path
checkpoint_path = r".\models\wind_direction_prediction3.ckpt"

#create a callback that saves the model's weight
ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,monitor='val_loss',
                                                 save_best_only=True,verbose=0,)

# %%
# %%time

EPOCHS = 500
batch_size = 6

model3 = model3_multilayer_perceptron_with_two_hidden_layer()
print('Here is a summary of this model: ')
model3.summary()

with tf.device('/CPU:0'):
    history = model3.fit(
        normed_train_data,
        train_labels,
        batch_size = batch_size,
        epochs=EPOCHS,
        verbose=0,
        shuffle=True,
        steps_per_epoch= 1,
        validation_data = (normed_valid_dataset, valid_labels),
        callbacks=[tfdocs.modeling.EpochDots(), ckpt_callback],
    )
# Out:
# Here is a summary of this model:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_26 (Dense)             (None, 32)                224
# _________________________________________________________________
# dense_27 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_29 (Dense)             (None, 72)                4680
# _________________________________________________________________
# dense_30 (Dense)             (None, 80)                5840
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 13,993
# Trainable params: 13,993
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, loss:28463.8066,  mae:159.7308,  mape:100.0463,  mse:28463.8066,  val_loss:29771.2363,  val_mae:164.6511,  val_mape:99.9763,  val_mse:29771.2363,
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ...........
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .......
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# Epoch: 100, loss:4027.2791,  mae:56.2040,  mape:51.3099,  mse:4027.2791,  val_loss:1963.2772,  val_mae:35.1584,  val_mape:23.7175,  val_mse:1963.2772,
# ....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ...
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ...........
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ........
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .......
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ......
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ...
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ...........
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ......
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ........
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ........
# ...
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ...............
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ...
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ...
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ......
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ...
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ........
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ...............
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# Epoch: 300, loss:3963.0029,  mae:51.1774,  mape:57.4030,  mse:3963.0029,  val_loss:1702.3953,  val_mae:32.0015,  val_mape:20.5503,  val_mse:1702.3953,
# .........
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ....
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .......................
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..........................................
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# .....
# Epoch: 400, loss:1786.3159,  mae:30.7893,  mape:20.3182,  mse:1786.3159,  val_loss:1637.0128,  val_mae:31.1078,  val_mape:19.8835,  val_mse:1637.0128,
# ..
# WARNING:absl:Found untraced functions such as activation_17_layer_call_and_return_conditional_losses, activation_17_layer_call_fn, activation_18_layer_call_and_return_conditional_losses, activation_18_layer_call_fn, activation_19_layer_call_and_return_conditional_losses while saving (showing 5 of 25). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# INFO:tensorflow:Assets written to: .\models\wind_direction_prediction3.ckpt\assets
# ..................................................................................................Wall time: 6min 16s
# Parser   : 115 ms

# %%
print('Summary of the results after each epoch: ')
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# Summary of the results after each epoch:
#             loss        mae          mse       mape     val_loss    val_mae  \
# 495   822.141846  26.244797   822.141846  17.700994  1637.821899  31.472811
# 496  3921.798096  43.452805  3921.798096  58.360779  2164.143799  36.707756
# 497  2349.347900  37.876080  2349.347900  19.309793  1773.504639  32.539806
# 498  1711.585571  36.456181  1711.585571  18.058107  1621.837280  31.452330
# 499  1212.519409  32.156628  1212.519409  23.145636  1658.686646  32.469387
#
#          val_mse   val_mape  epoch
# 495  1637.821899  20.273937    495
# 496  2164.143799  21.737947    496
# 497  1773.504639  20.182592    497
# 498  1621.837280  20.629372    498
# 499  1658.686646  22.000343    499

# %%
# Test the model after training
example_result_4 = model3.predict(normed_train_data)

# %% [markdown]
# ## Compare the Actual Values with the predicted values

# %%
print('Predicted Values')
print(example_result_4[:10])
print()
print('Actual Values')
print(train_labels[:10].to_string(index=False))
# Out:
# Predicted Values
# [[187.67448]
#  [192.30792]
#  [206.16678]
#  [151.49524]
#  [158.53925]
#  [215.64395]
#  [196.5922 ]
#  [187.1653 ]
#  [189.55682]
#  [222.91638]]
#
# Actual Values
# 236
# 209
# 307
#  99
# 131
# 190
# 210
# 170
# 210
# 199

# %% [markdown]
# ## See how the training went by plotting the loss/mse across epochs

# %%
plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)

plotter.plot({'Basic': history}, metric = 'mae')
plt.ylim([0,200])
plt.ylabel('MAE [wind-direction]')
# Out:
# Text(0, 0.5, 'MAE [wind-direction]')

# %%
plotter.plot({'Basic': history}, metric = 'mse')
plt.ylim([0,5000])
plt.ylabel('MSE [wind-direction]')
# Out:
# Text(0, 0.5, 'MSE [wind-direction]')

# %%
print('Error Rate on Train Split: ')
loss, mae, mse, mape = model3.evaluate(normed_train_data, train_labels, verbose=2)

print('Train set Mean Abs Error : {:5.2f}'.format(mae))
print('Train set Mean Square Error : {:5.2f}'.format(mse))
# Out:
# Error Rate on Train Split:
# 6/6 - 0s - loss: 1916.5621 - mae: 34.9172 - mse: 1916.5621 - mape: 26.5847
# Train set Mean Abs Error : 34.92
# Train set Mean Square Error : 1916.56

# %%
print('Error Rate on Evaluation  Split: ')
loss, mae, mse, mape = model3.evaluate(normed_valid_dataset, valid_labels, verbose=2)

print('Validation set Mean Abs Error : {:5.2f}'.format(mae))
print('Validation set Mean Square Error : {:5.2f}'.format(mse))
# Out:
# Error Rate on Evaluation  Split:
# 2/2 - 14s - loss: 1658.6866 - mae: 32.4694 - mse: 1658.6866 - mape: 22.0003
# Validation set Mean Abs Error : 32.47
# Validation set Mean Square Error : 1658.69

# %%
print('Error Rate on Test  Split: ')
loss, mae, mse, mape = model3.evaluate(normed_test_data, test_labels, verbose=2)

print('Testing set Mean Abs Error : {:5.2f}'.format(mae))
print('Testing set Mean Square Error : {:5.2f}'.format(mse))
# Out:
# Error Rate on Test  Split:
# 2/2 - 1s - loss: 1517.7189 - mae: 31.5163 - mse: 1517.7189 - mape: 21.1648
# Testing set Mean Abs Error : 31.52
# Testing set Mean Square Error : 1517.72

# %%
train_predictions = model3.predict(normed_train_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(train_labels, train_predictions)
plt.xlabel('True Values [wind-direction]')
plt.ylabel('Predictions [wind-direction]')
lims = [0, 350]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
test_predictions = model3.predict(normed_test_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [wind-direction]')
plt.ylabel('Predictions [wind-direction]')
lims = [0, 350]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
# error distribution.
error = test_predictions - test_labels
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error [wind-speed]")
_ = plt.ylabel("count")
